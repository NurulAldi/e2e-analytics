# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\UsEr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/E-commerce-Dataset.csv")
df.shape
# Out:
# (51290, 16)

# %%
df.dtypes
# Out:
# Order_Date              object
# Time                    object
# Aging                  float64
# Customer_Id              int64
# Gender                  object
# Device_Type             object
# Customer_Login_type     object
# Product_Category        object
# Product                 object
# Sales                  float64
# Quantity               float64
# Discount               float64
# Profit                 float64
# Shipping_Cost          float64
# Order_Priority          object
# Payment_method          object
# dtype: object

# %%
df.head()
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
# 1  2018-07-24  20:41:37    2.0        59173  Female         Web
# 2  2018-11-08  08:38:49    8.0        41066  Female         Web
# 3  2018-04-18  19:28:06    7.0        50741  Female         Web
# 4  2018-08-13  21:18:39    9.0        53639  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 1              Member  Auto & Accessories       Car Speakers  211.0       1.0
# 2              Member  Auto & Accessories    Car Body Covers  117.0       5.0
# 3              Member  Auto & Accessories    Car & Bike Care  118.0       1.0
# 4              Member  Auto & Accessories               Tyre  250.0       1.0
#
#    Discount  Profit  Shipping_Cost Order_Priority Payment_method
# ...

# %%
missing = df.isnull().mean().sort_values(ascending=False)
missing.head(20)
# Out:
# Order_Priority         0.000039
# Quantity               0.000039
# Aging                  0.000019
# Discount               0.000019
# Sales                  0.000019
# Shipping_Cost          0.000019
# Time                   0.000000
# Order_Date             0.000000
# Product_Category       0.000000
# Customer_Login_type    0.000000
# Device_Type            0.000000
# Gender                 0.000000
# Customer_Id            0.000000
# Product                0.000000
# Profit                 0.000000
# Payment_method         0.000000
# dtype: float64

# %%
for c in df.columns:
    if 'id' in c.lower():
        print('uniq id : ', df[c].nunique(), 'total rows', len(df))
# Out:
# uniq id :  38997 total rows 51290

# %%
for c in df.columns:
    if 'date' in c.lower() or 'time' in c.lower():
        print(c, pd.to_datetime(df[c], errors='coerce').agg(['min', 'max']))
# Out:
# Order_Date min   2018-01-01
# max   2018-12-30
# Name: Order_Date, dtype: datetime64[ns]
# C:\Users\UsEr\AppData\Local\Temp\ipykernel_6504\3780063441.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   print(c, pd.to_datetime(df[c], errors='coerce').agg(['min', 'max']))
# Time min   2025-09-27 00:00:06
# max   2025-09-27 23:59:58
# Name: Time, dtype: datetime64[ns]
